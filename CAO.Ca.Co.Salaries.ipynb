# %%
import pandas as pd

# %%
df = pd.read_csv('County CAO Salary Survey Results.csv', skiprows=1)

# %%
df.head()
# Out:
#       County 2009 Population               Name  \
# 0    Alameda      1,568,903     Susan Muranishi
# 1     Alpine          1,180        Pamela Knorr
# 2     Amador         37,964          Terri Daly
# 3      Butte        221,331   Gregory G Iturria
# 4  Calaveras         45,959       Robert Lawton
#
#                            Title  W-2, Box 5   Months Worked   \
# 0           County Administrator    $454,062              12
# 1  County Administrative Officer    $135,404              12
# 2   Chief Administrative Officer    $120,862              12
# 3   Chief Administrative Officer    $182,520              12
# 4  County Administrative Officer    $150,219              12
#
#                                             Comments
# 0  One time vacation sell back: $23,230. Vehicle ...
# 1                                                NaN
# 2  Ms. Daly is no longer Chief Administrative Off...
# 3                                                NaN
# 4    Vacation payout upon resignation December 2009.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/beetledore/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
df.columns
# Out:
# Index(['County', '2009 Population', 'Name', 'Title', ' W-2, Box 5 ',
#        ' Months Worked ', 'Comments'],
#       dtype='object')

# %%
import numpy as np

# %%
df[df[' W-2, Box 5 '] == 'No CAO'] = np.nan
df = df.dropna()
df[' W-2, Box 5 '] = df[' W-2, Box 5 '].str.replace('$', '')
df[' W-2, Box 5 '] = df[' W-2, Box 5 '].str.replace(',', '').astype(float)

# %%
df['2009 Population'] = df['2009 Population'].str.replace(',', '').astype(float)

# %%
df
# Out:
#             County  2009 Population                     Name  \
# 0          Alameda        1568903.0          Susan Muranishi
# 2           Amador          37964.0               Terri Daly
# 4        Calaveras          45959.0            Robert Lawton
# 6     Contra Costa        1068759.0                David Twa
# 7        Del Norte          29500.0       Jeannine Galatioto
# 8        El Dorado         181513.0        Gayle Erbe-Hamlin
# 9           Fresno         948928.0          John Navarrette
# 11        Humboldt         133269.0      Phillip Smith-Hanes
# 12        Imperial         181772.0         Ralph Cordova Jr
# 15           Kings         154681.0             Larry Spikes
# 16            Lake          64155.0             Kelly F. Cox
# 19          Madera         152924.0         Steven Rodriguez
# 20           Marin         259772.0         Matthew H. Hymel
# 21        Mariposa          18252.0        Richard J. Benson
# 23          Merced         257373.0           Larry T. Combs
# 24           Modoc           9699.0          Rick Rudometkin
# 27            Napa         138451.0               Nancy Watt
# 28          Nevada          98721.0           Richard Haffey
# 31          Plumas          20492.0          Jack W. Ingstad
# 33      Sacramento        1439985.0           Terry Schutten
# 35  San Bernardino        2064375.0        Mark Uffer (2009)
# 36       San Diego        3208466.0             Walter Ekard
# 39       San Mateo         750436.0             David Boesch
# 41    Santa Clara         1872049.0         Jeffrey V. Smith
# 42      Santa Cruz         270882.0       Susan A. Mauriello
# 45        Siskiyou          45983.0          Brian Mcdermott
# 46          Solano         426431.0       Michael D. Johnson
# 48      Stanislaus         527004.0         Richard Robinson
# 49          Sutter          97263.0      Stephanie J. Larsen
# %%
plt.plot(df['2009 Population'], df[' W-2, Box 5 '], '.')

# %%
from gender import gender

# %%
gender['LISA']
# Out:
# 'female'

# %%
gender_match = [gender[name.split()[0].upper()] if name.split()[0].upper() in gender.keys() else '' for name in df['Name']]

# %%
df['gender'] = gender_match

# %%
df
# Out:
#             County  2009 Population                     Name  \
# 0          Alameda        1568903.0          Susan Muranishi
# 2           Amador          37964.0               Terri Daly
# 4        Calaveras          45959.0            Robert Lawton
# 6     Contra Costa        1068759.0                David Twa
# 7        Del Norte          29500.0       Jeannine Galatioto
# 8        El Dorado         181513.0        Gayle Erbe-Hamlin
# 9           Fresno         948928.0          John Navarrette
# 11        Humboldt         133269.0      Phillip Smith-Hanes
# 12        Imperial         181772.0         Ralph Cordova Jr
# 15           Kings         154681.0             Larry Spikes
# 16            Lake          64155.0             Kelly F. Cox
# 19          Madera         152924.0         Steven Rodriguez
# 20           Marin         259772.0         Matthew H. Hymel
# 21        Mariposa          18252.0        Richard J. Benson
# 23          Merced         257373.0           Larry T. Combs
# 24           Modoc           9699.0          Rick Rudometkin
# 27            Napa         138451.0               Nancy Watt
# 28          Nevada          98721.0           Richard Haffey
# 31          Plumas          20492.0          Jack W. Ingstad
# 33      Sacramento        1439985.0           Terry Schutten
# 35  San Bernardino        2064375.0        Mark Uffer (2009)
# 36       San Diego        3208466.0             Walter Ekard
# 39       San Mateo         750436.0             David Boesch
# 41    Santa Clara         1872049.0         Jeffrey V. Smith
# 42      Santa Cruz         270882.0       Susan A. Mauriello
# 45        Siskiyou          45983.0          Brian Mcdermott
# 46          Solano         426431.0       Michael D. Johnson
# 48      Stanislaus         527004.0         Richard Robinson
# 49          Sutter          97263.0      Stephanie J. Larsen
# 51         Trinity          13924.0            Dero Forslund
# 54         Ventura         841001.0           Marty Robinson
# 55            Yolo         202220.0  Sharon Jensen (Retired)
#
#                                                 Title   W-2, Box 5   \
# 0                                County Administrator      454062.0
# 2                        Chief Administrative Officer      120862.0
# 4                       County Administrative Officer      150219.0
# 6                                                 CAO      250000.0
# 7                       County Administrative Officer      130974.0
# 8                        Chief Administrative Officer      201763.0
# 9                       County Administrative Officer      169150.0
# 11                      County Administrative Officer      122734.0
# 12                            Chief Executive Officer      189000.0
# 15                                                CAO      166000.0
# 16                      County Administrative Officer      143721.0
# 19                      County Administrative Officer       47668.0
# 20                                                CAO      253788.0
# 21                      County Administrative Officer      118145.0
# 23                           County Executive Officer       18333.0
# 24  Chief Administrative Officer/Director of Trans...      135000.0
# 27                           County Executive Officer      239711.0
# 28                           County Executive Officer      199791.0
# 31                                                CAO      133865.0
# 33                                   County Executive      384565.0
# 35                      County Administrative Officer      328000.0
# 36                       Chief Administrative Officer      309000.0
# 39                                     County Manager      303763.0
# 41                                   County Executive      107871.0
# 42                      County Administrative Officer      267556.0
# 45                               County Administrator      161000.0
# 46                               County Administrator      359954.0
# 48                            Chief Executive Officer      252233.0
# 49               Acting County Administrative Officer      138628.0
# 51                      County Administrative Officer       93861.0
# 54                           County Executive Officer      283083.0
# 55                               County Administrator      209536.0
#
#     Months Worked                                            Comments  gender
# 0              12   One time vacation sell back: $23,230. Vehicle ...  female
# 2              12   Ms. Daly is no longer Chief Administrative Off...  female
# 4              12     Vacation payout upon resignation December 2009.    male
# 6              12       Includes vehicle allowance of $600 per month.    male
# 7              12   The salary information above is the salary of ...  female
# 8              12   CAO pays full employee share of PERS which equ...  female
# 9              12                                                None    male
# 11             12   Mr. Smith-Hanes was appointed CAO in December ...    male
# 12             12   Includes sick leave and vacation buyback amoun...    male
# 15             12   Auto allowance of $6,000 per year voluntarily ...    male
# 16             12   Amount includes cash out of administrative lea...  female
# 19              4   CAO held position for 4 months in 2009. Annual...    male
# 20             12   Compensation includes $800 per month auto allo...    male
# 21             12                                                None    male
# 23              1   W-2, Box 5 figure reflects 1 month of work. An...    male
# 24             12   Temporary salary now. Total salary for both fu...    male
# 27             12   Includes phone and car allowance, and leave di...  female
# 28             12                  Includes $400 month auto allowance    male
# 31             12     CAO took a $10,000 pay reduction due to budget.    male
# 33             12   Includes $114,121 leave cashout on retirement,...    male
# 35             12   Medicare Wages includes an annual auto and cel...    male
# 36             12                                                None    male
# 39             12   Includes 100 hours of administrative leave cas...    male
# 41              4   W-2, Box 5 figure covers four months of work. ...    male
# 42             12   Includes employee payment to PERS at 7%; Admin...  female
# 45             12   Salary includes admin leave cash out, deferred...    male
# 46             12                                                None    male
# 48             12   Employer contribution to 457 Deferred Compensa...    male
# 49             12   Ms. Larsen was appointed Acting CAO effective ...  female
# 51             12      Same benefit package as other County employees
# 54             12                Includes leave redemption of $33,611    male
# 55              8   Of the total, $63,561.26 (fully taxable) repre...  female

# %%
df['annual'] = df[' W-2, Box 5 ']/df[' Months Worked '].astype(float)*12

# %%
df
# Out:
#             County  2009 Population                     Name  \
# 0          Alameda        1568903.0          Susan Muranishi
# 2           Amador          37964.0               Terri Daly
# 4        Calaveras          45959.0            Robert Lawton
# 6     Contra Costa        1068759.0                David Twa
# 7        Del Norte          29500.0       Jeannine Galatioto
# 8        El Dorado         181513.0        Gayle Erbe-Hamlin
# 9           Fresno         948928.0          John Navarrette
# 11        Humboldt         133269.0      Phillip Smith-Hanes
# 12        Imperial         181772.0         Ralph Cordova Jr
# 15           Kings         154681.0             Larry Spikes
# 16            Lake          64155.0             Kelly F. Cox
# 19          Madera         152924.0         Steven Rodriguez
# 20           Marin         259772.0         Matthew H. Hymel
# 21        Mariposa          18252.0        Richard J. Benson
# 23          Merced         257373.0           Larry T. Combs
# 24           Modoc           9699.0          Rick Rudometkin
# 24             12   Temporary salary now. Total salary for both fu...    male
# 27             12   Includes phone and car allowance, and leave di...  female
# 28             12                  Includes $400 month auto allowance    male
# 31             12     CAO took a $10,000 pay reduction due to budget.    male
# 33             12   Includes $114,121 leave cashout on retirement,...    male
# 35             12   Medicare Wages includes an annual auto and cel...    male
# 36             12                                                None    male
# 39             12   Includes 100 hours of administrative leave cas...    male
# 41              4   W-2, Box 5 figure covers four months of work. ...    male
# 42             12   Includes employee payment to PERS at 7%; Admin...  female
# 45             12   Salary includes admin leave cash out, deferred...    male
# 46             12                                                None    male
# 48             12   Employer contribution to 457 Deferred Compensa...    male
# 49             12   Ms. Larsen was appointed Acting CAO effective ...  female
# 51             12      Same benefit package as other County employees
# 54             12                Includes leave redemption of $33,611    male
# 55              8   Of the total, $63,561.26 (fully taxable) repre...  female
#
#       annual
# 0   454062.0
# 2   120862.0
# 4   150219.0
# 6   250000.0
# 7   130974.0
# 8   201763.0
# 9   169150.0
# 11  122734.0
# 12  189000.0
# 15  166000.0
# 16  143721.0
# 19  143004.0
# 20  253788.0
# 21  118145.0
# 23  219996.0
# 24  135000.0
# 27  239711.0
# 28  199791.0
# 31  133865.0
# 33  384565.0
# 35  328000.0
# 36  309000.0
# 39  303763.0
# 41  323613.0
# 42  267556.0
# 45  161000.0
# 46  359954.0
# 48  252233.0
# 49  138628.0
# 51   93861.0
# 54  283083.0
# 55  314304.0

# %%
total_male_sal = df.loc[df['gender'] == "male", 'annual'].sum()
total_male_sal
# Out:
# 4955903.0

# %%
total_fem_sal = df.loc[df['gender'] == "female", 'annual'].sum()

# %%
total_fem_sal
# Out:
# 2011581.0

# %%
#df.groupby('gender', 'female').count()
gender_cts = df['gender'].value_counts()

# %%
male_cts = gender_cts['male']
male_cts
# Out:
# 22

# %%
female_cts = gender_cts['female']

# %%
female_cts
# Out:
# 9

# %%
female_avg = int(total_fem_sal/female_cts)

# %%
female_avg
# Out:
# 223509

# %%
male_avg = int(total_male_sal/male_cts)
male_avg
# Out:
# 225268

# %%
import matplotlib.pyplot as plt

# %%
# Data to plot
labels = 'Women', 'Men'
sizes = [female_cts, male_cts]
colors = ['yellowgreen','lightskyblue']
 
# Plot
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.0f%%')
plt.title('Percentage of Women and Men Holding Executive Positions')
 
plt.axis('equal')
plt.show()

# %%
value_counts(female_avgs, male_avgs).plot(kind = "bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-5f095b93c4a1> in <module>()
# ----> 1 value_counts(female_avgs, male_avgs).plot(kind = "bar")
#
# NameError: name 'value_counts' is not defined

# %%
 
objects = ('Women', 'Men')
y_pos = np.arange(len(objects))
salarys = [female_avg, male_avg]
 
plt.barh(y_pos, salarys, align='center', alpha=0.5)
plt.yticks(y_pos, objects)
plt.xlabel('Salary')
plt.title('County Executives Salaries by Gender')
 
plt.show
# Out:
# <function matplotlib.pyplot.show>
